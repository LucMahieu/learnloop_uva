# %%
import os
# !streamlit run probleem_bepalen.py
# Out:
# ^C

# %% [markdown]
# # Probleem bepalen optimaliseren
# Dit mechanisme is ontworpen om een cursist te helpen in het bepalen van de probleemstelling die de cursist met de cursus hoopt op te lossen. De baseline werkt al redelijk goed, maar soms werkt het nog niet helemaal naar behoren.
#
# Het doel is daarom om dit mechanisme redelijk waterdicht te maken en advies te geven over wat er mogelijk nog aan verbeterd zou kunnen worden.
#
# ### Aanpak
# Verschillende inputs testen en vastleggen wat de reacties zijn en of deze gewenst zijn, en wat de gewenste output zou moeten zijn.
#
# Met deze informatie ga ik de prompt verbeteren en weer een iteratie doen.
#
# ### Test inputs
# Ik wil de reacties testen op het volgende gedrag:
# 1. Volledig ergens anders over praten dan het probleem.
# 2. Constant vaag blijven en niet de details geven die nodig zijn.
# 3. Tegenspreken van feedback.
# 4. Direct een goede probleemstelling geven.
# 5. Vragen stellen. "Waarom?", "Hoe?"
# 6. Aangeven dat je niet echt een probleem hebt in je bedrijf.
# 7. Onzinnig probleem beschrijven.
#
# ### Aantekeningen iteratie 1
# ##### Algemeen
# 1. Begint niet met een vraag terwijl je dat wel wil. De bot moet beginnen met een vraag.
# 2. Vraagt te algemeen naar "problemen met AI in bedrijven". Moet enkelvoud zijn en op het bedrijf van de persoon gericht zijn.
#
# #### Test inputs
# ##### 1. Volledig ergens anders over praten dan het probleem.
# Cursist: "Mijn oma heeft laatst heerlijke gebakjes gemaakt."
# App: "Dat klinkt heerlijk! We moeten echter focussen op het onderwerp van AI en Data in business. Kun je uitleggen wat precies het probleem is dat je wilt onderzoeken binnen dit domein?"
# Cursist: "Ja maar daar wil ik over praten"
# App: "Dat is begrijpelijk, maar om je goed te kunnen helpen, moeten we ons echt richten op het onderwerp AI en Data in business. Kun je een probleem of uitdaging benoemen die jouw organisatie ervaart met betrekking tot het gebruik van AI en data in haar bedrijfsprocessen?"
#
# **Status: check!**
#
# ##### 2. Constant vaag blijven en niet de details geven die nodig zijn.
# 🔘
# Mijn probleem gaat over AI en data
#
# 🔵
# Dat is een goede start. Laten we dat wat verder aan gaan scherpen.
#
# Wat is precies het probleem dat je hebt waargenomen met betrekking tot AI en data in een zakelijke context? Kun je een specifieke situatie of uitdaging beschrijven die je tegenkomt?
#
# 🔘
# Ja iets met te weinig
#
# 🔵
# Dank je. Kun je wat gedetailleerder zijn over wat er te weinig is? Gaat het bijvoorbeeld om te weinig data, te weinig kennis over AI, te weinig middelen, of misschien iets anders?
#
# 🔘
# Kennis
#
# 🔵
# Helder. Laten we dat verder uitwerken.
#
# Wat is het effect van de te weinig aanwezige kennis over AI en data binnen je bedrijf? Kun je beschrijven hoe dit zich uit en welk specifiek aspect van de bedrijfsvoering hierdoor wordt beïnvloed? Bijvoorbeeld, maakt het strategische besluitvorming moeilijker, vertraagt het de implementatie van AI-projecten, etc.?
#
# 🔘
# Keuzes maken
#
# 🔵
# Begrepen. Dus de beperkte kennis over AI en data beïnvloedt het vermogen van je bedrijf om goede keuzes te maken. Kun je aangeven welke specifieke keuzes of beslissingen hierdoor negatief worden beïnvloed? Bijvoorbeeld, keuzes met betrekking tot investeringen, klantstrategieën, operationele processen, etc.?
#
# 🔘
# Redelijk
#
# 🔵
# Goed, we beginnen nu een duidelijker beeld te krijgen.
#
# Kun je specifiek aangeven welke type beslissingen leiden tot problemen vanwege de gebrek aan kennis over AI en data, en hoe dat de bedrijfsresultaten beïnvloedt? Heb je een voorbeeld van zo'n beslissing en de consequenties daarvan?
#
# 🔘
# Welke leads
#
# 🔵
# Dank je voor de specificatie. Dus, de beperkte kennis over AI en data zorgt ervoor dat je bedrijf moeite heeft met het kiezen van de juiste leads.
#
# Kun je nu beschrijven hoe de beperkte kennis over AI en data de selectie van leads beïnvloedt? Bijvoorbeeld, worden er verkeerde leads geselecteerd, worden potentiële goede leads over het hoofd gezien, of is er inefficiëntie in het leadproces?
#
# 🔘
# Geen structuur
#
# 🔵
# Dat is nuttige informatie. Dus vanwege de beperkte kennis over AI en data ontbreekt er structuur in het proces van leadselectie.
#
# Kun je uitleggen welke specifieke onderdelen van het leadselectieproces niet goed werken door de gebrek aan kennis, en wat de directe gevolgen hiervan zijn voor de bedrijfsvoering? Bijvoorbeeld, hoe beïnvloedt het gebrek aan structuur de efficiëntie, tijdsbesparing, en uiteindelijk de opbrengsten?
#
# 🔘
# Meer fouten
#
# 🔵
# Duidelijk. Het ontbreken van structuur en de beperkte kennis leiden dus tot meer fouten bij het selecteren van leads.
#
# Kun je specifieker zijn over welke soorten fouten regelmatig voorkomen bij het leadselectieproces vanwege de beperkte kennis en de gebrekkige structuur? Bijvoorbeeld, worden er ongeschikte leads benaderd, wordt er verspilde tijd en middelen gebruikt, of worden potentiële waardevolle leads niet opgevolgd?
#
# 🔘
# Verspilede tijd aan geen potentie leads
#
# 🔵
# Goed, we hebben nu een stuk gedetailleerder inzicht in het probleem. De beperkte kennis over AI en data leidt tot een gebrek aan structuur, wat resulteert in het verspillen van tijd aan leads zonder potentie.
#
# Kun je aangeven wat voor soort kennis over AI en data er specifiek ontbreekt die zou kunnen helpen om deze verspilde tijd te verminderen? Bijvoorbeeld, kennis over data-analyse technieken, machine learning algoritmes, predictive analytics, of iets anders?
#
# **Status: check!**
#
# ### 3. Tegenspreken van feedback.
# 🔘
# Lets begin
#
# 🔵
# Prima! Laten we beginnen met het eerste aspect van je onderwerp. Kun je kort beschrijven wat je wilt bereiken of welk probleem je wilt aanpakken met betrekking tot AI en Data in business?
#
# 🔘
# Het gaat om betere marketingcampagnes met ai krijgen
#
# 🔵
# Dank je wel voor deze initiële uitleg. Om wat dieper op dit onderwerp in te gaan: wat zijn momenteel de specifieke problemen of uitdagingen die je tegenkomt bij het gebruik van AI in je marketingcampagnes?
#
# 🔘
# We gebruiken het niet omdat we te weinig kennis hebben in huis
#
# 🔵
# Dat is een nuttige informatie. Kun je nu aangeven welke gevolgen dit gebrek aan kennis over AI voor jullie marketingcampagnes heeft? Hebben jullie moeite met bepaalde aspecten zoals doelgroepsegmentatie, personalisatie, het meten van effectiviteit, enz.?
#
# 🔘
# We denken meer leads te kunnen genereren met personalisatie van ads
#
# 🔵
# Goed. Je hebt dus een specifieke uitdaging en een doel voor ogen. Om de probleemstelling verder te verfijnen: heb je enig idee welke aspecten van personalisatie jullie momenteel niet goed beheersen of waar AI specifiek zou kunnen helpen? Bijvoorbeeld, het analyseren van klantgegevens, het maken van klantprofielen, of het automatiseren van advertentie-inhoud?
#
# 🔘
# Ik vind dat geen nuttige informatie
#
# 🔵
# Dank je voor je feedback. Laten we het anders benaderen. Dus, jullie willen AI inzetten om marketingcampagnes te personaliseren en daarmee meer leads te genereren. Wat zijn de belangrijkste obstakels die jullie tegenhouden om AI te implementeren in jullie marketingstrategie? Bijvoorbeeld: gebrek aan technische vaardigheden, budgetbeperkingen, softwaretools, of managementondersteuning?
#
# 🔘
# Ik vind dat geen goede vraag
#
# 🔵
# Dank voor je geduld. Laten we het iets eenvoudiger maken. Wat hoop je precies te bereiken door AI toe te voegen aan je marketingcampagnes? Wat zijn de specifieke resultaten waar je naar streeft?
#
# **Status: Check!**
#
# ### 4. Direct een goede probleemstelling geven.
#
# ##### Evaluatie
# - **Geeft vraag in bijzonder format:**
#
# "Dat is een goede start. Laten we proberen dit verder te specificeren en helderder te maken. Om te beginnen:
#
# 1. Kun je specificeren welke specifieke soorten klantgegevens er momenteel zijn die onvoldoende worden gebruikt?"
#
# Komt mogelijk doordat hij meerdere vragen wilde stellen? We kunnen een voorbeeld output format geven in de prompt om dit te voorkomen.
#
# - **Gaat veel te lang door om het te specificeren**:
# Blijft continue doorvragen naar meer informatie terwijl ik echt al vaak de juiste info gegeven heb naar mijn idee.
# Ons bedrijf maakt momenteel onvoldoende gebruik van de beschikbare klantgegevens en de mogelijkheden van kunstmatige intelligentie (AI) om waardevolle inzichten te genereren en gepersonaliseerde klantinteracties te bieden. Het ontbreekt ons aan een geavanceerd systeem dat niet alleen klantgegevens verzamelt, maar deze ook analyseert en bruikbare inzichten biedt die direct kunnen worden toegepast om de klanttevredenheid te verbeteren en de verkoop te verhogen.
#
# 🔵
# Dat is een goede start. Laten we proberen dit verder te specificeren en helderder te maken. Om te beginnen:
#
# Kun je specificeren welke specifieke soorten klantgegevens er momenteel zijn die onvoldoende worden gebruikt?
# 🔘
# Transactiegegevens:
#
# Aankoopgeschiedenis: Gedetailleerde informatie over eerdere aankopen, inclusief producten/diensten, aankoopdatum, frequentie en uitgaven. Betalingsinformatie: Voorkeursbetaalmethode, betalingsgeschiedenis en eventuele betalingsproblemen. Demografische gegevens:
#
# Leeftijd, geslacht, en locatie: Basisinformatie die kan helpen bij het segmenteren van klanten en het personaliseren van aanbiedingen. Gezinsgrootte en burgerlijke staat: Informatie die relevant kan zijn voor bepaalde producten of diensten. Gedragsgegevens:
#
# Website- en app-gebruik: Pagina’s bezocht, tijd besteed aan verschillende secties, klikpatronen, en verlaten winkelwagens. Engagement met marketingcampagnes: Respons op e-mails, klikgedrag in nieuwsbrieven, en interacties met advertenties.
#
# 🔵
# Dat geeft ons een goed overzicht van de beschikbare klantgegevens. Laten we nu verder gaan met de volgende vraag:
#
# Welke specifieke uitdagingen ondervind je momenteel bij het analyseren en gebruiken van deze gegevens?
# 🔘
# We weten niet genoeg van AI om iets met die gegevens te kunnen.
#
# 🔵
# Begrijpelijk. Laten we nu verder specificeren:
#
# Wat is het uiteindelijke doel van het gebruik van AI binnen je bedrijf? Wat hoop je te bereiken door AI te implementeren in je gegevensanalyse?
# 🔘
# bruikbare inzichten biedt die direct kunnen worden toegepast om de klanttevredenheid te verbeteren en de verkoop te verhogen.
#
# 🔵
# Goed, dat maakt het doel helder. Laten we nu verder afbakenen:
#
# Wat zijn de belangrijkste obstakels momenteel die je weerhouden van het implementeren van een AI-systeem? Zijn deze technische, organisatorisch of beide?
# 🔘
# Vooral kennis en organisatorisch
#
# 🔵
# Helder. Laten we nu samenvatten wat we tot nu toe hebben besproken en de probleemstelling verder specificeren:
#
# Zijn er al bestaande systemen of technologieën in gebruik die verbeterd zouden kunnen worden, of moeten we helemaal vanaf nul beginnen?
# 🔘
# Vanaf nul
#
# 🔵
# Goed om te weten. Laten we verder gaan met de afbakening:
#
# Wat zijn de tijdsbesteding en budgetbeperkingen voor het opzetten en implementeren van een AI-systeem?
# 🔘
# 10000 en 3 maanden
#
# 🔵
# Dit helpt om de haalbaarheid van de probleemstelling te beoordelen. Laten we nu een concept probleemstelling opstellen op basis van de verstrekte informatie:
#
# Probleemstelling:
#
# Ons bedrijf beschikt over een schat aan klantgegevens, zoals transactiegegevens, demografische gegevens en gedragsgegevens, maar ontbreekt aan de kennis en organisatorische structuur om deze via kunstmatige intelligentie (AI) te analyseren. Hierdoor missen we kansen om waardevolle inzichten te genereren die de klanttevredenheid kunnen verbeteren en de verkoop kunnen verhogen. We hebben een budget van €10.000 en een tijdsbestek van drie maanden om een geavanceerd AI-systeem vanaf de grond op te bouwen dat klantgegevens kan verzamelen, analyseren en bruikbare inzichten biedt.
#
# ##### Evaluatie
# Het lijkt erop dat het heel graag alles super specifiek wil maken. Dat is goed, maar als je al zo uitgebreid antwoord gegeven hebt, kan dat vervelend voelen.
#
# **IMPORTANT:**
# Ook als ik de eindprobleemstelling terugvoer in een nieuwe chat, wil hij die blijven aanscherpen. Hiervoor zou misschien wel een betere evaluatie call gemaakt moeten worden.
#
# ### 5. Vragen stellen. "Waarom?", "Hoe?"
# - **Geeft de probleemstelling als ik zeg dat ik wil stoppen**
# 🔘
# Waarom
#
# 🔵
# De reden dat ik vraag naar de specifieke kennis en organisatorische structuren die ontbreken, is om meer helderheid en specificiteit aan de probleemstelling toe te voegen. Door deze details te verduidelijken, kunnen we ervoor zorgen dat de probleemstelling niet alleen duidelijker wordt, maar ook specifieker en beter afgebakend.
#
# Om verder te gaan, kun je aangeven welke specifieke kennis (bijvoorbeeld kennis van data-analysemethoden, AI-algoritmen, tooling) en organisatorische structuren (bijvoorbeeld teamstructuur, databeleid, integratieprocessen) je denkt dat momenteel ontbreken in je bedrijf?
#
# 🔘
# Hoe dan?
#
# 🔵
# Goed, laten we het stap voor stap doen. Laten we beginnen met de kennis die ontbreekt in jouw bedrijf. Kun je specifieker beschrijven wat voor soort kennis jullie missen als het gaat om het analyseren van klantgegevens met behulp van AI? Denk daarbij aan specifieke AI-technieken, data-analysetools, of vaardigheden die inhouse ontbreken.
#
# 🔘
# Maar ik wil niet meer verder
#
# 🔵
# Dat begrijp ik. Het is belangrijk dat je tevreden bent met de probleemstelling en de richting waarin je wilt gaan. Hier is een mogelijke geoptimaliseerde versie van je oorspronkelijke probleemstelling, gebaseerd op wat je al had:
#
# "Ons bedrijf beschikt over een aanzienlijke hoeveelheid klantgegevens, waaronder transactie-, demografische en gedragsgegevens, maar ontbeert de specifieke AI-expertise en organisatorische structuur om deze data effectief te analyseren. Hierdoor missen we belangrijke kansen om inzichten te genereren die de klanttevredenheid kunnen verbeteren en de verkoop kunnen stimuleren. Met een budget van €10.000 en een periode van drie maanden, is het onze doelstelling om een geavanceerd AI-systeem te ontwikkelen dat deze klantgegevens kan verzamelen, analyseren en bruikbare inzichten kan bieden."
#
# Deze versie is iets duidelijker en specifieker geformuleerd.
#
# Evaluatie van de geoptimaliseerde probleemstelling:
# Duidelijkheid: **** (4) - Vrij duidelijk en begrijpelijk.
# Relevantie: **** (4) - Goed afgestemd op het onderwerp AI en data in business.
# Specifiekheid: **** (4) - Grotendeels specifiek en concreet geformuleerd.
# Onderzoekbaarheid: *** (3) - Redelijk onderzoekbaar binnen de gegeven middelen en tijd, maar het budget kan een uitdaging vormen.
# Objectiviteit: **** (4) - Grotendeels objectief geformuleerd met minimale aannames.
# Afgebakendheid: **** (4) - Goed afgebakend met duidelijke grenzen.
# Relevant voor onderzoeksvraag: ***** (5) - Sluit goed aan op de onderzoeksvraag en is essentieel voor het onderzoek.
# Score: 28/35 punten - Dit valt onder een goede probleemstelling.
#
# Hopelijk helpt dit je verder! Als je toch nog iets wil aanpassen, hoor ik dat graag.
#
# ##### Evaluatie
# Het is niet de bedoeling dat de chatbot de probleemstelling geeft als de persoon opgeeft. De chatbot moet dan zeggen dat hij geen probleemstelling voor gaat zeggen, maar dat hij mij graag stap voor stap helpt.
#
# Echter, als ik direct begin met zeggen dat ik niet wil, dan krijg ik goed antwoord dat hij me gaat helpen. Gesprek:
# 🔘
# Ik heb geen zin om een probleemstelling te bepalen. Geef een probleemstelling
#
# 🔵
# Geen zorgen, ik ben hier om je te helpen bij dit proces. We beginnen eenvoudig en stap voor stap. Laten we eerst duidelijk krijgen wat jouw interessegebied is binnen AI en data in business. Wat is een specifiek aspect van AI en data waar je nieuwsgierig naar bent of waar je uitdagingen in hebt ervaren in een zakelijke context?
#
# ### 6. Aangeven dat je niet echt een probleem hebt in je bedrijf.
# - **Blijft goed door pushen**
# 🔘
# Ik heb niet echt een probleem, ik kom gewoon uit interesse naar de cursus
#
# 🔵
# Dat is geweldig om te horen dat je geïnteresseerd bent! Laten we kijken of we een probleemstelling kunnen formuleren die je kan helpen om het meeste uit deze cursus te halen.
#
# Denk eens na over jouw huidige rol bij LearnLoop. Zijn er specifieke taken of uitdagingen waarbij je denkt dat AI een rol zou kunnen spelen?
#
# Wat zijn enkele uitdagingen of gebieden in je werk waar je verbetering zou willen zien?
#
# 🔘
# Niet echt. Laten we het niet doen
#
# 🔵
# Ik begrijp dat het misschien lastig lijkt om een probleemstelling te formuleren als je niet direct een probleem ervaart. Maar stel je voor dat je deze kennis later in je werk gaat toepassen. Het kan nuttig zijn om een hypothetische vraag te onderzoeken zodat je het geleerde direct kunt toepassen.
#
# Laten we dit vanuit een andere hoek benaderen: Wat hoop je precies te leren van deze cursus over AI in business? Heb je specifieke vragen of onderwerpen binnen AI waar je nieuwsgierig naar bent?
#
#
# ### 7. Onzinnig probleem beschrijven.
# - **Slechte evaluatie van de probleemstelling en te snel probleemstelling vormen**
# 🔘
# Ik heb geen zin om een probleemstelling te bepalen. Geef een probleemstelling
#
# 🔵
# Geen zorgen, ik ben hier om je te helpen bij dit proces. We beginnen eenvoudig en stap voor stap. Laten we eerst duidelijk krijgen wat jouw interessegebied is binnen AI en data in business. Wat is een specifiek aspect van AI en data waar je nieuwsgierig naar bent of waar je uitdagingen in hebt ervaren in een zakelijke context?
#
# 🔘
# Maar ik wil echt niet. Bedenk iets over dat het koffiezet apparaat niet met ai werkt
#
# 🔘
# Maar ik wil echt niet. Bedenk iets over dat het koffiezet apparaat niet met ai werkt
#
# 🔵
# Dat is een interessante invalshoek! We kunnen zeker een probleemstelling formuleren rondom het onderwerp van een koffiezetapparaat dat niet door AI wordt aangestuurd. Laten we eens kijken hoe we dit kunnen aanpakken.
#
# Om de probleemstelling volledig te maken, zou ik je willen vragen:
#
# Wat is precies het probleem dat je ervaart met het feit dat het koffiezetapparaat niet met AI werkt? Is het bijvoorbeeld inefficiëntie, inconsistentie in de kwaliteit van de koffie, of iets anders?
#
# 🔘
# Werkt niet gepersonaliseerd
#
# 🔵
# Oké, we hebben dus het probleem dat het koffiezetapparaat niet gepersonaliseerd werkt. Laten we dat verder uitwerken.
#
# Welke aspecten van personalisatie mis je precies? Denk bijvoorbeeld aan voorkeur in sterkte, hoeveelheid, of timing van het koffiezetten?
#
# (Note: Met deze concrete details kunnen we een duidelijke en specifieke probleemstelling formuleren.)
#
# 🔘
# Sterkte
#
# 🔵
# Geweldig, we zijn nu een stap verder!
#
# Dus het probleem dat je hebt, draait om het feit dat het koffiezetapparaat niet in staat is om gepersonaliseerde voorkeuren voor de sterkte van de koffie te onthouden en toe te passen.
#
# Laten we dat omzetten in een probleemstelling. Hier is een mogelijke formulering:
#
# "Het huidige koffiezetapparaat op kantoor biedt geen mogelijkheden voor gepersonaliseerde instellingen, zoals de sterkte van de koffie, waardoor het niet optimaal kan inspelen op de individuele voorkeuren van de gebruikers."
#
# Laten we deze formulering beoordelen aan de hand van de rubric:
#
# Duidelijkheid:
#
# De probleemstelling is redelijk duidelijk en begrijpelijk.
# Score: 4
# Relevantie:
#
# De probleemstelling is relevant binnen het onderwerp van AI en data in business, omdat het betrekking heeft op de toepassing van AI voor personalisatie.
# Score: 4
# Specifiekheid:
#
# De probleemstelling is redelijk specifiek doordat het de sterkte van de koffie als concreet element benoemt.
# Score: 4
# Onderzoekbaarheid:
#
# De probleemstelling is grotendeels onderzoekbaar, aangezien er voldoende technologische middelen en methoden zijn om dit probleem aan te pakken.
# Score: 4
# Objectiviteit:
#
# De probleemstelling is objectief geformuleerd en bevat geen aannames.
# Score: 5
# Afgebakendheid:
#
# De probleemstelling is goed afgebakend door het specifieke probleem van gepersonaliseerde sterkte aan te wijzen.
# Score: 4
# Relevant voor onderzoeksvraag:
#
# De probleemstelling sluit goed aan op het verkennen van AI's rol in personalisatie binnen een zakelijke context.
# Score: 4
# Totale score: 29 punten
#
# Deze probleemstelling valt in de categorie van een "Goede probleemstelling" volgens de rubric. Als je wilt dat we nog verder verbeteren, kunnen we dit nog verder verfijnen. Wat denk je ervan?
#
# ##### Evaluatie
# Ik gaf in het gesprek aan dat ik geen probleemstelling wilde bepalen en toen vroeg hij door. Dat was goed, maar ging te snel over op de probleemstelling zelf maken en ook nog goed beoordelen.
#
#
# **IMPORTANT:** er is geen voorbeeld van de eind probleemstelling en ook geen voorbeeld van hoe de evaluatie met de rubric eruit moet zien als die getoond wordt.
#
#
# ## Eind evaluatie
# Belangrijkste problemen zijn:
# - De persoon moet nu het gesprek starten, terwijl de chatbot dat moet doen.
# - De evaluatie is niet consistent of accuraat, waardoor hij soms te snel het goed vindt of te lang doorgaat.
#
# ## Mogelijke oplossingen
# - Chat als eerste laten beginnen zodra je op een button drukt met vragen.
# - Een losse evaluatie call maken voor betere consistente beoordeling en die score + verbeterpunten teruggeeft waarmee de main chat een nieuwe vraag kan stellen oid.
# - Als iemand een goede probleemstelling al heeft, dan moet de chat niet verder specifieker maken, maar gewoon zeggen dat het goed is (indien goed beoordeelt met rubric).
# - Onderzoeken hoe goed mensen hun problemen kennen en begrijpen en hoe goed ze dat weten te verwoorden. Dat beïnvloedt de reacties van de chat.
#
# Losse evaluatie en die goed samen laten werken kan een uitdaging zijn. Ik verwacht dat je daar 4 uur mee bezig bent om dat goed te optimaliseren.
